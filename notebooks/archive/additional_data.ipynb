# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import mne
import mne_bids
#%matplotlib inline
# %matplotlib qt

# %%
# this works only with mne and mne_bids installed

# %%
path_to_data = '../../BIDS_EEG_meditation_experiment/'

# %%
raw_edf = mne_bids.read_raw_bids('sub-001_ses-01_task-meditation_eeg.bdf', path_to_data)
# Out:
# Extracting EDF parameters from /home/sam/proj/epfl/eeg-meditation/BIDS_EEG_meditation_experiment/sub-001/ses-01/eeg/sub-001_ses-01_task-meditation_eeg.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 696575  =      0.000 ...  2720.996 secs...
# Reading events from ../../BIDS_EEG_meditation_experiment/sub-001/ses-01/eeg/sub-001_ses-01_task-meditation_events.tsv.
# Reading channel info from ../../BIDS_EEG_meditation_experiment/sub-001/ses-01/eeg/sub-001_ses-01_task-meditation_channels.tsv.
# <ipython-input-17-b505d04fdd19>:1: RuntimeWarning: The unit for channel(s) Status has changed from NA to V.
#   raw_edf = mne_bids.read_raw_bids('sub-001_ses-01_task-meditation_eeg.bdf', path_to_data)

# %%
raw_edf.plot()

# %%
events = mne.find_events(raw_edf, initial_event=True, consecutive=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/opt/miniconda3/envs/eegmed/lib/python3.8/site-packages/mne/event.py in find_events(raw, stim_channel, output, consecutive, min_duration, shortest_event, mask, uint_cast, mask_type, initial_event, verbose)
#     683     try:
# --> 684         stim_channel = _get_stim_channel(stim_channel, raw.info)
#     685     except ValueError:
#
# ~/.local/opt/miniconda3/envs/eegmed/lib/python3.8/site-packages/mne/utils/config.py in _get_stim_channel(stim_channel, info, raise_error)
#     407     elif raise_error:
# --> 408         raise ValueError("No stim channels found. Consider specifying them "
#     409                          "manually using the 'stim_channel' parameter.")
#
# ValueError: No stim channels found. Consider specifying them manually using the 'stim_channel' parameter.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-2b740424a8ab> in <module>
# ----> 1 events = mne.find_events(raw_edf, initial_event=True, consecutive=True)
#
# </home/sam/.local/opt/miniconda3/envs/eegmed/lib/python3.8/site-packages/mne/externals/decorator.py:decorator-gen-137> in find_events(raw, stim_channel, output, consecutive, min_duration, shortest_event, mask, uint_cast, mask_type, initial_event, verbose)
#
# ~/.local/opt/miniconda3/envs/eegmed/lib/python3.8/site-packages/mne/utils/_logging.py in wrapper(*args, **kwargs)
#      88             with use_log_level(verbose_level):
#      89                 return function(*args, **kwargs)
# ---> 90         return function(*args, **kwargs)
#      91     return FunctionMaker.create(
#      92         function, 'return decfunc(%(signature)s)',
#
# ~/.local/opt/miniconda3/envs/eegmed/lib/python3.8/site-packages/mne/event.py in find_events(raw, stim_channel, output, consecutive, min_duration, shortest_event, mask, uint_cast, mask_type, initial_event, verbose)
#     685     except ValueError:
#     686         if len(raw.annotations) > 0:
# --> 687             raise ValueError("No stim channels found, but the raw object has "
#     688                              "annotations. Consider using "
#     689                              "mne.events_from_annotations to convert these to "
#
# ValueError: No stim channels found, but the raw object has annotations. Consider using mne.events_from_annotations to convert these to events.

# %%
events = mne.events_from_annotations(raw_edf)
# Out:
# Used Annotations descriptions: ['n/a']

# %%
raw_edf.plot_psd(fmax=50); # this works
# Out:
# Effective window size : 8.000 (s)
# <ipython-input-28-5b3107fc8a49>:1: UserWarning: Infinite value in PSD for channel(s) GSR2, Temp. These channels might be dead.
#   raw_edf.plot_psd(fmax=50);
# <ipython-input-28-5b3107fc8a49>:1: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   raw_edf.plot_psd(fmax=50);

# %%
raw_edf.plot(events=events)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-545c8697eb64> in <module>
# ----> 1 raw_edf.plot(events=events)
#
# ~/.local/opt/miniconda3/envs/eegmed/lib/python3.8/site-packages/mne/io/base.py in plot(self, events, duration, start, n_channels, bgcolor, color, bad_color, event_color, scalings, remove_dc, order, show_options, title, show, block, highpass, lowpass, filtorder, clipping, show_first_samp, proj, group_by, butterfly, decim, noise_cov, event_id, show_scrollbars, verbose)
#    1560              butterfly=False, decim='auto', noise_cov=None, event_id=None,
#    1561              show_scrollbars=True, verbose=None):
# -> 1562         return plot_raw(self, events, duration, start, n_channels, bgcolor,
#    1563                         color, bad_color, event_color, scalings, remove_dc,
#    1564                         order, show_options, title, show, block, highpass,
#
# </home/sam/.local/opt/miniconda3/envs/eegmed/lib/python3.8/site-packages/mne/externals/decorator.py:decorator-gen-132> in plot_raw(raw, events, duration, start, n_channels, bgcolor, color, bad_color, event_color, scalings, remove_dc, order, show_options, title, show, block, highpass, lowpass, filtorder, clipping, show_first_samp, proj, group_by, butterfly, decim, noise_cov, event_id, show_scrollbars, verbose)
#
# ~/.local/opt/miniconda3/envs/eegmed/lib/python3.8/site-packages/mne/utils/_logging.py in wrapper(*args, **kwargs)
#      88             with use_log_level(verbose_level):
#      89                 return function(*args, **kwargs)
# ---> 90         return function(*args, **kwargs)
#      91     return FunctionMaker.create(
#      92         function, 'return decfunc(%(signature)s)',
#
# ~/.local/opt/miniconda3/envs/eegmed/lib/python3.8/site-packages/mne/viz/raw.py in plot_raw(raw, events, duration, start, n_channels, bgcolor, color, bad_color, event_color, scalings, remove_dc, order, show_options, title, show, block, highpass, lowpass, filtorder, clipping, show_first_samp, proj, group_by, butterfly, decim, noise_cov, event_id, show_scrollbars, verbose)
#     319         raise TypeError('title must be None or a string')
#     320     if events is not None:
# --> 321         event_times = events[:, 0].astype(float) - raw.first_samp
#     322         event_times /= info['sfreq']
#     323         event_nums = events[:, 2]
#
# TypeError: tuple indices must be integers or slices, not tuple
